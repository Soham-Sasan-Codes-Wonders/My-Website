# %%
import matplotlib.pyplot as plt
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]
data = [21, 69, 420, 89]
plt.plot(time, position, data)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
#test for Plotting.
# Out:
# Text(0, 0.5, 'Position (km)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('data.csv')
year = [1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980]
price = [1.42, 1.38, 1.37, 1.4, 1.5, 1.62, 1.74, 2, 2.54, 2.87, 3.28, 3.68, 4.12, 4.95]
plt.xlabel('Year')
plt.ylabel('Price of Gas')
plt.plot(year, price)

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
data = pd.read_csv('data.csv')
year = []
